# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("artist_data.csv")
data.head(3533)
# Out:
#          id                    name  gender      dates  yearOfBirth  \
# 0     10093  Abakanowicz, Magdalena  Female  born 1930       1930.0
# 1         0     Abbey, Edwin Austin    Male  1852–1911       1852.0
# 2      2756        Abbott, Berenice  Female  1898–1991       1898.0
# 3         1  Abbott, Lemuel Francis    Male  1760–1803       1760.0
# 4       622          Abrahams, Ivor    Male  born 1935       1935.0
# ...     ...                     ...     ...        ...          ...
# 3527  12542         Zorio, Gilberto    Male  born 1944       1944.0
# 3528   2186              Zox, Larry    Male  born 1936       1936.0
# 3529    621   Zuccarelli, Francesco    Male  1702–1788       1702.0
# 3530   2187        Zuloaga, Ignacio    Male  1870–1945       1870.0
# 3531   2188         Zyw, Aleksander    Male  1905–1995       1905.0
#
#       yearOfDeath                    placeOfBirth            placeOfDeath  \
# 0             NaN                          Polska                     NaN
# ...

# %%
data['placeOfBirth'].value_counts()[:10].plot(kind='bar', title='Top 10 countries:\nGive birth talented artist')
# Out:
# <AxesSubplot:title={'center':'Top 10 countries:\nGive birth talented artist'}>

# %%
#During the data exploration I followed the tutorial step by step and I wanted to know what countries the 
#artists were born in, because when I browsed the database I found that most of the artists were born in the UK, 
#so I made a graph to see the top 10 most popular countries. At first I wanted to show all countries, I used "[:]" 
#but I found that there were too many countries and many of them had similar percentages, so I just chose the top 10.

# %%
import pandas as pd

# %%
data2=pd.read_csv("artwork_data.csv")
data2.head(69203)
# Out:
# /var/folders/zt/661jnz253rs8bbqxh65g2k7r0000gn/T/ipykernel_79730/951466922.py:1: DtypeWarning: Columns (9,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data2=pd.read_csv("artwork_data.csv")
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# ...

# %%
data2[data2['artist'] == 'Cruzvillegas, Abraham']
# Out:
#            id accession_number                 artist artistRole  artistId  \
# 69096  106713           T13765  Cruzvillegas, Abraham     artist     13142
# 69097  106714           T13766  Cruzvillegas, Abraham     artist     13142
# 69098  106715           T13767  Cruzvillegas, Abraham     artist     13142
# 69099  106716           T13768  Cruzvillegas, Abraham     artist     13142
# 69100  106717           T13769  Cruzvillegas, Abraham     artist     13142
# 69101  106718           T13770  Cruzvillegas, Abraham     artist     13142
# 69102  106719           T13771  Cruzvillegas, Abraham     artist     13142
# 69103  106720           T13772  Cruzvillegas, Abraham     artist     13142
# 69104  106721           T13773  Cruzvillegas, Abraham     artist     13142
# 69105  106722           T13774  Cruzvillegas, Abraham     artist     13142
# 69106  106723           T13775  Cruzvillegas, Abraham     artist     13142
# ...

# %%
#I filtered out all the artworks of the author Cruzvillegas, Abraham
