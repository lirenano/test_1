# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.max_rows =(999)
data=pd.read_csv("副本science fiction.csv")

# %%
data_clean = data.dropna(axis=0, how='any', inplace=False)

# %%
data_clean
# Out:
#                               Book_Title  \
# 0                                 Utopia
# 1                     Gulliver's Travels
# 2            Frankenstein: The 1818 Text
# 3            Frankenstein: The 1818 Text
# 4                           The Last Man
# ...                                  ...
# 14923                    Leviathan Falls
# 14924                     Winter's Orbit
# 14925                 Fugitive Telemetry
# 14926  The Galaxy, and the Ground Within
# 14927                  Light of the Jedi
#
#                                      Original_Book_Title  \
# 0      Libellus vere aureus, nec minus salutaris quam...
# 1       Travels into Several Remote Nations of the World
# 2               Frankenstein; or, The Modern Prometheus
# 3               Frankenstein; or, The Modern Prometheus
# 4                                          The Last Man
# ...                                                  ...
# 14923  \n                  0356510395\n              ...
# ...

# %%
labels = data_clean['Genre*'].str.split(',', expand=True)
labels
sns.countplot(data=labels, x=0,order=labels[0].value_counts().iloc[:5].index) 
plt.xticks(rotation=90)
plt.title('The top 5 most popular science fiction genres ')
plt.xlabel('Genre')
plt.show()

# %% [markdown]
# It can be seen that among the many genres of science fiction, the five most popular ones account for almost the same number, but the themes of aliens and space travel still account for a higher percentage than the others.
